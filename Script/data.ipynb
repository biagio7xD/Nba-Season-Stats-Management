# %%
import pandas as pd

# %%
full = pd.read_csv("CSV_Files/nba.csv")
team = pd.read_csv("CSV_Files/teams.csv")

# %%
team
# Out:
#     LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION       NICKNAME  \
# 0           0  1610612737      1949      2019          ATL          Hawks
# 1           0  1610612738      1946      2019          BOS        Celtics
# 2           0  1610612740      2002      2019          NOP       Pelicans
# 3           0  1610612741      1966      2019          CHI          Bulls
# 4           0  1610612742      1980      2019          DAL      Mavericks
# 5           0  1610612743      1976      2019          DEN        Nuggets
# 6           0  1610612745      1967      2019          HOU        Rockets
# 7           0  1610612746      1970      2019          LAC       Clippers
# 8           0  1610612747      1948      2019          LAL         Lakers
# 9           0  1610612748      1988      2019          MIA           Heat
# 10          0  1610612749      1968      2019          MIL          Bucks
# 11          0  1610612750      1989      2019          MIN   Timberwolves
# ...

# %%
full
# Out:
#     TeamID                TeamName TeamAbbr  Gms     MP    FG   FGA    FGP  \
# 0        1   Golden State Warriors      GSW   82  19730  3509  6981  0.503
# 1        2         Houston Rockets      HOU   82  19755  3174  6906  0.460
# 2        3    New Orleans Pelicans      NOP   82  19955  3500  7241  0.483
# 3        4         Toronto Raptors      TOR   82  19830  3383  7169  0.472
# 4        5     Cleveland Cavaliers      CLE   82  19730  3311  6950  0.476
# 5        6          Denver Nuggets      DEN   82  19880  3338  7102  0.470
# 6        7      Philadelphia 76ers      PHI   82  19780  3349  7098  0.472
# 7        8  Minnesota Timberwolves      MIN   82  19805  3365  7063  0.476
# 8        9    Los Angeles Clippers      LAC   82  19705  3302  7004  0.471
# 9       10       Charlotte Hornets      CHO   82  19780  3197  7106  0.450
# 10      11      Los Angeles Lakers      LAL   82  19905  3338  7248  0.461
# ...

# %%
full.iloc[20,2] = 'PHX'
full.iloc[9,2] = 'CHA'
full.iloc[13,2] = 'BKN'

# %%
full = pd.merge(full, team[['TEAM_ID', 'NICKNAME', 'ABBREVIATION']], how='left', left_on='TeamAbbr', right_on='ABBREVIATION')

# %%
full.drop(['ABBREVIATION_x', 'ABBREVIATION_y'], axis=1, inplace=True)

# %%
df = pd.read_csv("CSV_Files/full_player.csv")

# %%
df
# Out:
#               Name Pos  Age  Gms  Gstart    MP   FG  FGA    FGP  ThreeP  ...  \
# 0     Alex Abrines  SG   24   75       8  1134  115  291  0.395      84  ...
# 1       Quincy Acy  PF   27   70       8  1359  130  365  0.356     102  ...
# 2     Steven Adams   C   24   76      76  2487  448  712  0.629       0  ...
# 3      Bam Adebayo   C   20   69      19  1368  174  340  0.512       0  ...
# 4    Arron Afflalo  SG   32   53       3   682   65  162  0.401      27  ...
# ..             ...  ..  ...  ...     ...   ...  ...  ...    ...     ...  ...
# 600   Tyler Zeller   C   28   42      33   703  125  229  0.546      10  ...
# 601   Tyler Zeller   C   28   24       1   406   62  105  0.590       0  ...
# 602    Paul Zipser  SF   23   54      12   824   81  234  0.346      37  ...
# 603     Ante Zizic   C   21   32       2   214   49   67  0.731       0  ...
# 604    Ivica Zubac   C   20   43       0   410   61  122  0.500       0  ...
#
# ...

# %%
df = df.merge(full[['TeamID', 'TEAM_ID']], how='left', on='TeamID')

# %%
full.drop("TeamID", axis=1, inplace=True)

# %%
df.to_csv("CSV_Files/player.csv", index=False)
full.to_csv("CSV_Files/nba.csv", index=False)
